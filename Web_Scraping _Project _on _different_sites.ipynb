# %% [markdown]
# <h1 align=center style=color:black> Web Scraping Project on Different sites website<h1/>

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd
import csv

# %% [markdown]
# <h2 align=center style=color:red>  Scraping a  Population Table from Worldometers website<h2/>

# %%
url = "https://www.worldometers.info/world-population/" # This site is Worldometers which tell the real time population of world

# %%
page = requests.get(url)

# %%
page        #if it is 200 then it means we can scrap data from this site.
# Out:
# <Response [200]>

# %%
html = BeautifulSoup(page.text, "lxml")

# %%
table = html.find("table","table table-striped table-bordered table-hover table-condensed table-list")

# %%
table
# Out:
# <table class="table table-striped table-bordered table-hover table-condensed table-list"><thead> <tr> <th>Year<br/> (July 1) </th><th>Population</th><th>Yearly % <br/> Change</th><th>Yearly<br/> Change</th><th>Median <br/>Age</th><th>Fertility <br/>Rate</th><th>Density <br/>(P/Km²)</th> </tr><tr> <td>2020</td> <td><strong>7,794,798,739</strong></td> <td>1.05 %</td> <td>81,330,639</td> <td>30.9</td> <td>2.47</td> <td>52</td> </tr> <tr> <td>2019</td> <td><strong>7,713,468,100</strong></td> <td>1.08 %</td> <td>82,377,060</td> <td>29.8</td> <td>2.51</td> <td>52</td> </tr></thead><tbody><tr> <td>2018</td> <td><strong>7,631,091,040</strong></td> <td>1.10 %</td> <td>83,232,115</td> <td>29.8</td> <td>2.51</td> <td>51</td> </tr><tr> <td>2017</td> <td><strong>7,547,858,925</strong></td> <td>1.12 %</td> <td>83,836,876</td> <td>29.8</td> <td>2.51</td> <td>51</td> </tr><tr> <td>2016</td> <td><strong>7,464,022,049</strong></td> <td>1.14 %</td> <td>84,224,910</td> <td>29.8</td> <td>2.51</td> <td>50
# ...

# %%
t_headers = table.find_all("th")

# %%
t_headers
# Out:
# [<th>Year<br/> (July 1) </th>,
#  <th>Population</th>,
#  <th>Yearly % <br/> Change</th>,
#  <th>Yearly<br/> Change</th>,
#  <th>Median <br/>Age</th>,
#  <th>Fertility <br/>Rate</th>,
#  <th>Density <br/>(P/Km²)</th>]

# %%
headers = []
for i in t_headers:
    title = i.text
    headers.append(title)

# %%
headers
# Out:
# ['Year (July 1) ',
#  'Population',
#  'Yearly %  Change',
#  'Yearly Change',
#  'Median Age',
#  'Fertility Rate',
#  'Density (P/Km²)']

# %%
df = pd.DataFrame(columns = headers)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Year (July 1) , Population, Yearly %  Change, Yearly Change, Median Age, Fertility Rate, Density (P/Km²)]
# Index: []

# %% [markdown]
# #### Using nested method to scrap the rows of a table while leaving header

# %%
table.find_all("tr")[1:]
# Out:
# [<tr> <td>2020</td> <td><strong>7,794,798,739</strong></td> <td>1.05 %</td> <td>81,330,639</td> <td>30.9</td> <td>2.47</td> <td>52</td> </tr>,
#  <tr> <td>2019</td> <td><strong>7,713,468,100</strong></td> <td>1.08 %</td> <td>82,377,060</td> <td>29.8</td> <td>2.51</td> <td>52</td> </tr>,
#  <tr> <td>2018</td> <td><strong>7,631,091,040</strong></td> <td>1.10 %</td> <td>83,232,115</td> <td>29.8</td> <td>2.51</td> <td>51</td> </tr>,
#  <tr> <td>2017</td> <td><strong>7,547,858,925</strong></td> <td>1.12 %</td> <td>83,836,876</td> <td>29.8</td> <td>2.51</td> <td>51</td> </tr>,
#  <tr> <td>2016</td> <td><strong>7,464,022,049</strong></td> <td>1.14 %</td> <td>84,224,910</td> <td>29.8</td> <td>2.51</td> <td>50</td> </tr>,
#  <tr> <td>2015</td> <td><strong>7,379,797,139</strong></td> <td>1.19 %</td> <td>84,594,707</td> <td>30</td> <td>2.52</td> <td>50</td> </tr>,
# ...

# %%
for j in table.find_all("tr")[1:]:
    row_data = j.find_all("td")
    row = [tr.text for tr in row_data]
    length = len(df)
    df.loc[length] = row

# %%
df
# Out:
#    Year (July 1)      Population Yearly %  Change Yearly Change Median Age  \
# 0            2020  7,794,798,739           1.05 %    81,330,639       30.9
# 1            2019  7,713,468,100           1.08 %    82,377,060       29.8
# 2            2018  7,631,091,040           1.10 %    83,232,115       29.8
# 3            2017  7,547,858,925           1.12 %    83,836,876       29.8
# 4            2016  7,464,022,049           1.14 %    84,224,910       29.8
# 5            2015  7,379,797,139           1.19 %    84,594,707         30
# 6            2010  6,956,823,603           1.24 %    82,983,315         28
# 7            2005  6,541,907,027           1.26 %    79,682,641         27
# 8            2000  6,143,493,823           1.35 %    79,856,169         26
# 9            1995  5,744,212,979           1.52 %    83,396,384         25
# 10           1990  5,327,231,061           1.81 %    91,261,864         24
# ...

# %% [markdown]
# #### Exporting this table into csv or excel

# %%
df.to_csv('table_scraped.csv')

# %%
df.to_excel("table_scrapped.xlsx")

# %%
df.to_excel("table_scraped.xlsx", index = False)

# %% [markdown]
# <h2 align=center style=color:green> Scraping a 2022  NFL League Standings Table <h2/>

# %%
 url = "https://www.nfl.com/standings/league/2022/REG"

# %%
page1 = requests.get(url)

# %%
nfl = BeautifulSoup(page1.text , "lxml")

# %%
table1 = nfl.find("table",{"summary":"Standings - Detailed View"})

# %%
header = nfl.find_all("th")

# %%
header_list = []
for i in header:
    list = i.text.strip()
    header_list.append(list)

# %%
header_list
# Out:
# ['NFL Team',
#  'W',
#  'L',
#  'T',
#  'PCT',
#  'PF',
#  'PA',
#  'Net Pts',
#  'Home',
#  'Road',
#  'Div',
#  'Pct',
#  'Conf',
#  'Pct',
#  'Non-Conf',
#  'Strk',
#  'Last 5']

# %%
df1 = pd.DataFrame(columns = header_list)

# %%
df1
# Out:
# Empty DataFrame
# Columns: [NFL Team, W, L, T, PCT, PF, PA, Net Pts, Home, Road, Div, Pct, Conf, Pct, Non-Conf, Strk, Last 5]
# Index: []

# %%
 tr1 = table1.find_all('tr')[1:]

# %%
for j in tr1:
    first_td = j.find_all("td")[0].find("div",class_ ="d3-o-club-fullname").text.strip()
    row_data = j.find_all("td")[1:]
    data = [td.text.strip() for td in row_data]
    data.insert(0,first_td)
    length1 = len(df1)
    df1.loc[length1] = data

# %%
df1.head(15)
# Out:
#                 NFL Team  W   L  T    PCT   PF   PA Net Pts       Home  \
# 0         Houston Texans  1  12  1  0.107  235  344    -109  0 - 6 - 1
# 1          Chicago Bears  3  11  0  0.214  290  358     -68  2 - 5 - 0
# 2      Arizona Cardinals  4  10  0  0.286  292  372     -80  1 - 7 - 0
# 3         Denver Broncos  4  10  0  0.286  218  253     -35  3 - 4 - 0
# 4     Indianapolis Colts  4   9  1  0.321  245  337     -92  2 - 4 - 0
# 5       Los Angeles Rams  4   9  0  0.308  218  296     -78  3 - 5 - 0
# 6        Atlanta Falcons  5   9  0  0.357  306  333     -27  4 - 3 - 0
# 7      Carolina Panthers  5   9  0  0.357  276  314     -38  4 - 4 - 0
# 8      Green Bay Packers  5   8  0  0.385  263  302     -39  3 - 3 - 0
# 9     New Orleans Saints  5   9  0  0.357  286  315     -29  4 - 4 - 0
# 10      Cleveland Browns  6   8  0  0.429  313  326     -13  4 - 3 - 0
# 11  Jacksonville Jaguars  6   8  0  0.429  334  328       6  4 - 3 - 0
# ...

# %%
df1.to_csv("table1_scraped.csv")

# %%
df1.to_excel("table1_scraped.xlsx")

# %% [markdown]
# <h2 align=center style=color:green> Scraping Data for a Random Problem <h2/>

# %% [markdown]
# ### Problem Statement 1:
#
# Write a python code using web scraping method for creating a list of<br>
# 1) Name of Diseases,<br>
# 2) URLs associated with diseases and,<br>
# 3) Icon images of diseases.<br>
# Save the list as a CSV file.<br>
# Create the folder using python commands to save the icon images.<br>
# URL of webpage: https://dermnetnz.org/image-library <br>

# %%
! pip install selenium

# %%
### Imorting libraries
import csv
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd

# %%
# Creating an instance of webdriver for google chrome
driver = webdriver.Chrome()

# %%
# Using webdriver we'll now open the dermnetnz website in chrome
url =  'https://dermnetnz.org/image-library'
# We;ll use the get method of driver and pass in the URL
driver.get(url)

# %%
print(url)
# Out:
# https://dermnetnz.org/image-library

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
# Total no. of  wanted data present in this page
results=soup.find_all('a',{'class':"imageList__group__item"})
len(results)
# Out:
# 294

# %%
# picking the 1st card from the complete list of cards
item = results[0]

# %% [markdown]
# ###  Extracting data for single diseases

# %%
# Extracting the name of Diseases from the 1st card
name = item.find('div',{'class':"imageList__group__item__copy"}).text.strip()
name
# Out:
# 'Acne affecting the back images'

# %%
# Extracting the urls of Diseases from the 1st card
urls='https://dermnetnz.org' + soup.find('a' ,{'class':"imageList__group__item"},href=True)['href']
urls
# Out:
# 'https://dermnetnz.org/topics/acne-affecting-the-back-images/?stage=Live'

# %% [markdown]
# ###  Extracting all data points of name and urls

# %%
# Define a function for both name and urls for single data
def extract_name_url(item):
    name = item.find('div',{'class':"imageList__group__item__copy"}).text.strip()
    urls='https://dermnetnz.org' + soup.find('a' ,{'class':"imageList__group__item"},href=True)['href']
    file=(name,urls)
    return file

# %%
# creating a list of all name and urls
lists = []
results = soup.find_all('a',{'class':"imageList__group__item"})
for item in results:
    lists.append(extract_name_url(item))

# %%
# creating a pandas dataframe
pd.DataFrame(lists,columns=['name','urls'])
# Out:
#                                                  name  \
# 0                      Acne affecting the back images
# 1                      Acne affecting the face images
# 2           Acne and other follicular disorder images
# 3    Acquired dermal macular hyperpigmentation images
# 4                   Acral lentiginous melanoma images
# ..                                                ...
# 289                    Vulval lichen sclerosus images
# 290                               Vulval ulcer images
# 291                   Vulvovaginal candidiasis images
# 292                                Xanthelasma images
# 293                      Xeroderma pigmentosum images
#
#                                                   urls
# 0    https://dermnetnz.org/topics/acne-affecting-th...
# 1    https://dermnetnz.org/topics/acne-affecting-th...
# 2    https://dermnetnz.org/topics/acne-affecting-th...
# 3    https://dermnetnz.org/topics/acne-affecting-th...
# ...

# %%
# save file into csv
pd.DataFrame(lists,columns=['name','urls']).to_csv('Diseases_name and urls')

# %% [markdown]
# ###  Extracting all urls of image

# %%
# finding all img html tag
image_tags = soup.find_all('img')

# %%
# Creating a list of urls of images
links = []
for image_tag in image_tags:
    try:
        links.append(image_tag['src'])
    except:
        pass

# %%
# length of list
len(links)
# Out:
# 299

# %%
links
# Out:
# ['//in.getclicky.com/101371808ns.gif',
#  'https://static.adsafeprotected.com/skeleton.gif',
#  'https://www.gstatic.com/images/branding/googlelogo/1x/googlelogo_color_42x16dp.png',
#  'https://dermnetnz.org/assets/manualthumbnails/acne/acne-back/preview/141__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/Screen-Shot-2018-01-25-at-8__FocusFillWzE1MCwxMTAsIngiLDFd.28.37-PM.png',
#  'https://dermnetnz.org/assets/Uploads/ocular-rosacea-s__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/scaly/lp-pigmentosus1__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/20160516-165503__FocusFillWzE1MCwxMTAsInkiLDFd.JPG',
#  'https://dermnetnz.org/assets/Uploads/248__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/393__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/478__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
# ...

# %%
links=links[2:296]
links
# Out:
# ['https://www.gstatic.com/images/branding/googlelogo/1x/googlelogo_color_42x16dp.png',
#  'https://dermnetnz.org/assets/manualthumbnails/acne/acne-back/preview/141__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/Screen-Shot-2018-01-25-at-8__FocusFillWzE1MCwxMTAsIngiLDFd.28.37-PM.png',
#  'https://dermnetnz.org/assets/Uploads/ocular-rosacea-s__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/scaly/lp-pigmentosus1__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/20160516-165503__FocusFillWzE1MCwxMTAsInkiLDFd.JPG',
#  'https://dermnetnz.org/assets/Uploads/248__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/393__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/478__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
#  'https://dermnetnz.org/assets/Uploads/418__FocusFillWzE1MCwxMTAsInkiLDFd.jpg',
# ...

# %%
len(links)
# Out:
# 294

# %%
import requests
import os

# %%
# Creating a file
os.mkdir('Diseases_names')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9972/239786527.py in <module>
#       1 # Creating a file
# ----> 2 os.mkdir('Diseases_names')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Diseases_names'

# %%
for i in range(0,len(links)):
    r = requests.get(links[i])
    with open(f'Diseases_names/image{i+1}.jpg', "wb") as f:
        f.write(r.content)

# %% [markdown]
# <h2 align=center style=color:blue> Scraping Airbnb Site and dealing with multiple pages website<h2/>

# %%
url1 =   "https://www.airbnb.co.in/s/Goa--India/homes?tab_id=home_tab&refinement_paths%5B%5D=%2Fhomes&flexible_trip_lengths%5B%5D=one_week&price_filter_input_type=0&price_filter_num_nights=1&query=Goa%2C%20India&place_id=ChIJQbc2YxC6vzsRkkDzYv-H-Oo&date_picker_type=calendar&checkin=2023-01-20&checkout=2023-01-21&source=structured_search_input_header&search_type=autocomplete_click&federated_search_session_id=56ff82a7-a82f-409d-b469-7b0860fc220e&pagination_search=true&cursor=eyJzZWN0aW9uX29mZnNldCI6MCwiaXRlbXNfb2Zmc2V0IjowLCJ2ZXJzaW9uIjoxfQ%3D%3D"

# %%
page5 = requests.get (url1)

# %%
page5
# Out:
# <Response [200]>

# %%
airbnb = BeautifulSoup(page5.text , "lxml")

# %%
airbnb
# Out:
# <!DOCTYPE html>
# <html data-hyperloop-version="1" data-is-hyperloop="true" dir="ltr" lang="en-IN"><head><meta charset="utf-8"/><meta content="en-IN" name="locale"/><meta content="notranslate" name="google"/><meta content="authenticity_token" id="csrf-param-meta-tag" name="csrf-param"/><meta content="" id="csrf-token-meta-tag" name="csrf-token"/><meta content="" id="english-canonical-url"/><meta content="on" name="twitter:widgets:csp"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="Airbnb" name="application-name"/><meta content="Airbnb" name="apple-mobile-web-app-title"/><meta content="#ffffff" name="theme-color"/><meta content="#ffffff" name="msapplication-navbutton-color"/><meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/><meta content="/?utm_source=homescreen" name="msapplication-starturl"/><script>(function() {
#   var pgRequest = new XMLHttpRequest();
# ...

# %%
df6 = pd.DataFrame({"Link":[""],"Title" :[""], "Detail":[""],"Rating" :[""],"Price":[""],"Address":[""]})

# %% [markdown]
# #### Forming the loop for multiple pages

# %%
counter = 0

while counter <15:
    

    postings = airbnb.find_all("div", class_ = "c4mnd7m dir dir-ltr" )
    for post in postings:
        try:


            link = post.find("a", class_ ="bn2bl2p dir dir-ltr").get("href")
            link_full = "https://www.airbnb.co.in" + link
            title = post.find("div", class_ = "t1jojoys dir dir-ltr" ).text
            price = post.find("span" , class_ ="a8jt5op dir dir-ltr").text
            rating = post.find("span", class_ = "r1dxllyb dir dir-ltr").text
            details = post.find("span" , class_ = "dir dir-ltr").text
            address = post.find("span", class_ = "t6mzqp7 dir dir-ltr").text
            df6 = df6.append({"Link":link_full,"Title" :title, "Detail":details,"Rating" :rating,"Price":price,"Address":address},ignore_index = True)
        except:
            pass






    next_page = airbnb.find("a",{"aria-label" :"Next"}).get("href")
    next_page_full = "https://www.airbnb.co.in" + next_page

    
    page5 = requests.get(next_page_full)
    airbnb = BeautifulSoup(page5.text, "lxml")
    counter += 1

# %%
df6.head(18)
# Out:
#                                                  Link  \
# 0
# 1   https://www.airbnb.co.in/rooms/39852455?check_...
# 2   https://www.airbnb.co.in/rooms/54025171?check_...
# 3   https://www.airbnb.co.in/rooms/53581101?check_...
# 4   https://www.airbnb.co.in/rooms/53070736?check_...
# 5   https://www.airbnb.co.in/rooms/28402869?check_...
# 6   https://www.airbnb.co.in/rooms/34329273?check_...
# 7   https://www.airbnb.co.in/rooms/741726654862114...
# 8   https://www.airbnb.co.in/rooms/776594341478860...
# 9   https://www.airbnb.co.in/rooms/47764225?check_...
# 10  https://www.airbnb.co.in/rooms/10623757?check_...
# 11  https://www.airbnb.co.in/rooms/14959951?check_...
# 12  https://www.airbnb.co.in/rooms/45921975?check_...
# 13  https://www.airbnb.co.in/rooms/734405036084481...
# 14  https://www.airbnb.co.in/rooms/32086143?check_...
# 15  https://www.airbnb.co.in/rooms/40524398?check_...
# 16  https://www.airbnb.co.in/rooms/745239709403553...
# ...

# %% [markdown]
# ###  Saving file into excel and csv

# %%
df6.to_csv("rooms_scraped.csv")

# %%
df6.to_excel("rooms_scraped.xlsx")

# %% [markdown]
# <h2 align=center style=color:red> Scraping Carpages site and dealing with multiple pages <h2/>

# %%
url10  = "https://www.carpages.ca/used-cars/search/?fueltype_id%5B0%5D=3&fueltype_id%5B1%5D=7"

# %%
page10 = requests.get(url10)

# %%
page10
# Out:
# <Response [200]>

# %%
carpages = BeautifulSoup(page10.text,"lxml")

# %%
carpages
# Out:
# <!DOCTYPE html>
# <!--
#                                 ______________
#                         __..=='|'   |         ``-._
#            \=====_..--'/'''    |    |              ``-._
#            |'''''      ```---..|____|_______________[)>.``-.._____
#            |\_______.....__________|____________     ''  \      __````---.._
#          ./'     /.-'_'_`-.\       |  ' '       ```````---|---/.-'_'_`=.-.__```-._
#          |.__  .'/ /     \ \`.      \                     | .'/ /     \ \`. ```-- `.
#           \  ``|| |   o   | ||-------\-------------------/--|| |   o   | ||--------|
#            "`--' \ \ _ _ / / |______________________________| \ \ _ _ / / |..----```
#                   `-.....-'                                    `-.....-'
#
#                ______
#               / ____/___ __________  ____ _____ ____  _____ _________ _
#              / /   / __ `/ ___/ __ \/ __ `/ __ `/ _ \/ ___// ___/ __ `/
# ...

# %%
postings10 = carpages.find_all("div", class_ = "media soft push-none rule")

# %%
postings10
# Out:
# [<div class="media soft push-none rule">
#  <a class="media__img media__img--thumb" href="/used-cars/ontario/mississauga/2016-hyundai-sonata-9412099/" title="Used 2016 Hyundai Sonata Hybrid Limited for sale in Mississauga, ON">
#  <div class="fit-img">
#  <img alt="Used 2016 Hyundai Sonata Hybrid Limited for sale in Mississauga, ON" class="round lazy" data-original="https://images.carpages.ca/inventory/9412099.338624611?w=320&amp;h=240&amp;q=75&amp;s=cc234a772eea13e666a707d85ff089db" src="/images/primary/placeholder/no-photo-anim.svg"/>
#  <noscript>
#  <img alt="Used 2016 Hyundai Sonata Hybrid Limited for sale in Mississauga, ON" src="https://images.carpages.ca/inventory/9412099.338624611?w=320&amp;h=240&amp;q=75&amp;s=cc234a772eea13e666a707d85ff089db"/>
#  </noscript>
#  </div>
#  </a>
#  <div class="media__content">
#  <div class="l-row">
#  <div class="l-column l-column--large-8">
#  <hgroup class="push-half--bottom">
#  <h4 class="hN">
# ...

# %%
df10 = pd.DataFrame({"Link":[""],"Name":[""],"Price":[""],"KM_Run":[""],"Color":[""]})

# %% [markdown]
# #### Forming the loop for multiple pages

# %%
counter = 0  
    
while counter <15:
    postings10 = carpages.find_all("div", class_ = "media soft push-none rule")
    
    for post in postings10:
            link = post.find("a",{"class" :"media__img media__img--thumb"}).get("href")
            link_full = "https://www.carpages.ca" + link
            name = post.find("h4", class_ = "hN").text.strip()
            price = post.find("strong", class_ = "delta").text
            km_run = post.find_all("div", {"class" :"grey l-column l-column--small-6 l-column--medium-4"})[0].text.strip()
            color = post.find_all("div", {"class" :"grey l-column l-column--small-6 l-column--medium-4"})[1].text.strip()
            df10 = df10.append({"Link": link_full ,"Name":name ,"Price":price,"KM_Run":km_run,"Color":color},ignore_index = True)

    next_page = carpages.find("a",{"class":"nextprev"}).get("href")
    next_page_full = "https://www.carpages.ca" + next_page
    page10 = requests.get(next_page_full)
    carpages = BeautifulSoup(page10.text,"lxml")
    counter += 1

# %%
df10
# Out:
#                                                   Link  \
# 0
# 1    https://www.carpages.ca/used-cars/ontario/miss...
# 2    https://www.carpages.ca/new-cars/british-colum...
# 3    https://www.carpages.ca/new-cars/british-colum...
# 4    https://www.carpages.ca/used-cars/british-colu...
# ..                                                 ...
# 731  https://www.carpages.ca/new-cars/manitoba/winn...
# 732  https://www.carpages.ca/new-cars/manitoba/winn...
# 733  https://www.carpages.ca/new-cars/manitoba/winn...
# 734  https://www.carpages.ca/new-cars/manitoba/winn...
# 735  https://www.carpages.ca/new-cars/manitoba/winn...
#
#                        Name  \
# 0
# 1       2016 Hyundai Sonata
# 2    2022 Chrysler Pacifica
# 3          2022 Ford Escape
# 4      2022 Hyundai Elantra
# ..                      ...
# 731            2023 Audi Q5
# 732            2023 Audi Q5
# 733            2023 Audi Q5
# 734            2023 Audi Q5
# 735            2023 Audi Q5
#
# ...

# %% [markdown]
# ### Saving file into excel and csv

# %%
df10.to_csv("cars_scraped.csv")

# %%
df10.to_excel("cars.scraped.xlsx")
